# %% [markdown]
# ### Complementing a Strand of DNA
# http://rosalind.info/problems/revc/

# %%
DNA_String = "..."[::-1] # Initializing and Reversing the String
#print(DNA_String)
for i in DNA_String:
    if i == "A":
        Compl_A = "T"
        print(Compl_A, end = '')
    elif i == "T":
        Compl_T = "A"
        print(Compl_T,end = '')
    elif i == "G":
        Compl_G = "C"
        print(Compl_G, end ='')
    elif i == "C":
        Compl_C = "G"
        print(Compl_C, end= '')
    else:
        pass
# Out:
# ...
