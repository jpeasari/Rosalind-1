# %% [markdown]
# ### Counting Point Mutations
# http://rosalind.info/problems/hamm/

# %%
x = "GAGCCTACTAACGGGAT"
y = "CATCGTAATGACGGCCT"
x1 = list(x)
y1 = list(y)
z = len(x1)
sum = 0
for i in range(len(x1)):
    if x[i] != y[i]:
        sum = sum + 1
print(sum)
# Out:
# 7
